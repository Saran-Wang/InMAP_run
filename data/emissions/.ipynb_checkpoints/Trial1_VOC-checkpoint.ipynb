# %%
import salem
import xarray

# %%
data = xarray.open_dataset("C:/Users/15311/Desktop/emissions/bioburn.nc")

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize']=(20,9)
mpl.style.use('ggplot')
data.NOx.plot(cmap="RdBu_r")

# %%
# GeoPandas' GeoDataFrame

df_shp = salem.read_shapefile(r'C:/Users/15311/Desktop/natural_earth_vector/10m_cultural/ne_10m_admin_0_countries.shp')
# https://unstats.un.org/unsd/methodology/m49/ for ISO-alpha3 code

usa_shp = df_shp.loc[df_shp['ADM0_A3'].isin(['USA'])]
usa_shp.head()
# Out:
#           featurecla  scalerank  LABELRANK                SOVEREIGNT SOV_A3  \
# 153  Admin-0 country          0          2  United States of America    US1
#
#      ADM0_DIF  LEVEL     TYPE                     ADMIN ADM0_A3  ...  \
# 153         1      2  Country  United States of America     USA  ...
#
#                        NAME_RU NAME_SV                      NAME_TR  NAME_VI  \
# 153  Соединённые Штаты Америки     USA  Amerika Birleşik Devletleri   Hoa Kỳ
#
#     NAME_ZH                                           geometry       min_x  \
# 153      美国  (POLYGON ((-95.16056921399991 49.3694941210001... -179.143503
#
#           max_x      min_y      max_y
# 153  179.780935  18.906117  71.412502
#
# [1 rows x 99 columns]

# %%
VOC_subset = data.VOC.salem.subset(shape=usa_shp,margin=1)
VOC_roi = VOC_subset.salem.roi(shape=usa_shp)
VOC_roi
# Out:
# C:\Users\15311\AppData\Local\Continuum\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\15311\AppData\Local\Continuum\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <xarray.DataArray 'VOC' (lat: 211, lon: 1426)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
VOC_roi.salem.quick_map()
# Out:
# C:\Users\15311\AppData\Local\Continuum\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-23aafe580552> in <module>()
# ----> 1 VOC_roi.salem.quick_map()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\salem\sio.py in quick_map(self, ax, interp, **kwargs)
#     703     def quick_map(self, ax=None, interp='nearest', **kwargs):
#     704         """Make a plot of the DataArray."""
# --> 705         return self._quick_map(self._obj, ax=ax, interp=interp, **kwargs)
#     706
# ...

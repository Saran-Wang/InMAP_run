# %%
import os

path = "../data/ceds/2014"
files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f)) and f[-3:]==".nc"]

#[print(f) for f in files]

# %%
import netCDF4

# Get area of grid cells
area = netCDF4.Dataset("../data/ceds/CEDS_gridcell_area_05.nc", "r").variables["gridcell area"][:] # m^2

sectors = ["agr", "ene", "ind", "rco", "shp", "slv", "tra", "wst"]
pols = [p.split("-")[0] for p in files]

print(pols)

vocs = ['ALD2', 'ALK4_butanes', 'ALK4_hexanes', 'ALK4_pentanes', 'BENZ', 'BUTENE', 
        'C2H2', 'C2H4', 'C2H6', 'C3H8', 'CH2O', 'CHC', 'EOH', 'ESTERS', 'ETHERS', 
        'MEK', 'OTHER_AROM', 'OTHER_VOC', 'PRPE', 'TMB', 'TOLU', 'XYLE', 'HCOOH']
pm = ['BC', 'OC'] # I think we can assume both BC and OC are pm2.5?

noToNOx = 1.0 / 0.65 # Convert NO-based mass to NO2-based mass (the opposite of what is done in CEDS_edit.sh)

# Emissions units = kg m-2 s-1
ugperkg = 1.0e9

dims = {}

for sector in sectors:
    out = netCDF4.Dataset('ceds_%s.nc'%sector, 'w', format='NETCDF3_64BIT_OFFSET', clobber=True)
    for pol in pols:
        if pol in vocs: outpol = "VOC"
        elif pol in pm: outpol = "PM2_5"
        elif pol == "NO": outpol = "NOx"
        elif pol == "SO2": outpol = "SOx"
        else: outpol = pol
        
        f = '%s-em-anthro_CMIP_CEDS_2014.nc'%pol
        filepath = os.path.join(path, f)
        rootgrp = netCDF4.Dataset(filepath, "r")
        
        if len(dims) == 0:
            for d in ["lat", "lon"]: dims[d] = rootgrp.dimensions[d]
        
        v = '%s_%s'%(pol, sector)
        data = rootgrp.variables[v][:].sum(axis=0) # remove time dimension
        data = data * ugperkg * area # New units: μg/s
        if pol == "NO": data = data * noToNOx
        
        s = data.sum()
        if s==0.0: continue
        print(sector, pol, outpol, data.sum(), "μg/s")
        
        if len(out.dimensions) == 0:
            for d in dims: out.createDimension(d,size=dims[d].size)
            for vname in ["lat", "lon"]:
                rootvar = rootgrp.variables[vname]
                x = out.createVariable(vname, rootvar.datatype, rootvar.dimensions)
                x[:] = rootvar[:]
                x.setncatts(rootvar.__dict__)
        
        if outpol not in out.variables.keys(): 
            vout = out.createVariable(outpol, 'f8', rootgrp.variables[v].dimensions[1:])
            vout.units = "ug s-1"
            vout.long_name = rootgrp.variables[v].long_name.replace(pol, outpol)
            out.variables[outpol][:] = data
        else: out.variables[outpol][:] = out.variables[outpol][:] + data
    out.close()
# Out:
# ['ALD2', 'ALK4_butanes', 'ALK4_hexanes', 'ALK4_pentanes', 'BC', 'BENZ', 'BUTENE', 'C2H2', 'C2H4', 'C2H6', 'C3H8', 'CH2O', 'CH4', 'CHC', 'CO', 'CO2', 'EOH', 'ESTERS', 'ETHERS', 'HCOOH', 'MEK', 'NH3', 'NO', 'OC', 'OTHER_AROM', 'OTHER_VOC', 'PRPE', 'SO2', 'TMB', 'TOLU', 'XYLE']
# agr CH4 CH4 5.23954e+13 μg/s
# agr NH3 NH3 1.73753e+13 μg/s
# agr NO NOx 2.24246e+12 μg/s
# ene ALD2 VOC 4.4975e+10 μg/s
# ene ALK4_butanes VOC 4.43319e+12 μg/s
# ene ALK4_hexanes VOC 2.4519e+12 μg/s
# ene ALK4_pentanes VOC 5.36491e+12 μg/s
# ene BC PM2_5 4.53405e+11 μg/s
# ene BENZ VOC 6.98564e+11 μg/s
# ene BUTENE VOC 7.5177e+11 μg/s
# ene C2H2 VOC 1.41767e+10 μg/s
# ene C2H4 VOC 5.52911e+11 μg/s
# ene C2H6 VOC 1.22238e+12 μg/s
# ene C3H8 VOC 1.72579e+12 μg/s
# ene CH2O VOC 5.62587e+11 μg/s
# ene CH4 CH4 5.8684e+13 μg/s
# ene CO CO 1.85942e+13 μg/s
# ene CO2 CO2 5.91865e+15 μg/s
# ene EOH VOC 2.12521e+11 μg/s
# ene HCOOH VOC 3.18072e+11 μg/s
# ene MEK VOC 6.83333e+10 μg/s
# ene NH3 NH3 3.25718e+11 μg/s
# ene NO NOx 1.29985e+13 μg/s
# ene OC PM2_5 7.80441e+11 μg/s
# ene OTHER_AROM VOC 1.74463e+11 μg/s
# ene OTHER_VOC VOC 5.85888e+11 μg/s
# ene PRPE VOC 5.56039e+10 μg/s
# ene SO2 SOx 1.8183e+13 μg/s
# ene TMB VOC 2.66674e+10 μg/s
# ene TOLU VOC 6.2978e+11 μg/s
# ene XYLE VOC 5.02099e+11 μg/s
# ind ALD2 VOC 1.06955e+10 μg/s
# ind ALK4_butanes VOC 3.46448e+11 μg/s
# ind ALK4_hexanes VOC 6.66484e+11 μg/s
# ind ALK4_pentanes VOC 3.67399e+11 μg/s
# ind BC PM2_5 3.18291e+11 μg/s
# ind BENZ VOC 1.55373e+11 μg/s
# ind BUTENE VOC 3.25615e+11 μg/s
# ind C2H2 VOC 3.45905e+10 μg/s
# ind C2H4 VOC 2.94204e+11 μg/s
# ind C2H6 VOC 5.99896e+10 μg/s
# ind C3H8 VOC 1.37698e+11 μg/s
# ind CH2O VOC 1.30025e+11 μg/s
# ind CH4 CH4 3.38664e+11 μg/s
# ind CO CO 4.91519e+13 μg/s
# ind CO2 CO2 3.39714e+15 μg/s
# ind EOH VOC 5.08805e+10 μg/s
# ind HCOOH VOC 2.3854e+11 μg/s
# ind MEK VOC 1.62503e+10 μg/s
# ind NH3 NH3 4.81209e+11 μg/s
# ind NO NOx 7.51286e+12 μg/s
# ind OC PM2_5 5.58531e+11 μg/s
# ind OTHER_AROM VOC 3.71319e+11 μg/s
# ind OTHER_VOC VOC 6.83223e+11 μg/s
# ind PRPE VOC 3.21171e+10 μg/s
# ind SO2 SOx 1.63312e+13 μg/s
# ind TMB VOC 6.57332e+09 μg/s
# ind TOLU VOC 3.30003e+11 μg/s
# ind XYLE VOC 8.88013e+11 μg/s
# rco ALD2 VOC 5.58505e+11 μg/s
# rco ALK4_butanes VOC 1.37218e+11 μg/s
# rco ALK4_hexanes VOC 1.75553e+11 μg/s
# rco ALK4_pentanes VOC 2.30772e+11 μg/s
# rco BC PM2_5 1.41245e+12 μg/s
# rco BENZ VOC 1.28485e+12 μg/s
# rco BUTENE VOC 1.0276e+12 μg/s
# rco C2H2 VOC 8.15428e+11 μg/s
# rco C2H4 VOC 4.89688e+10 μg/s
# rco C2H6 VOC 9.94004e+11 μg/s
# rco C3H8 VOC 3.24455e+11 μg/s
# rco CH2O VOC 1.70163e+11 μg/s
# rco CH4 CH4 4.60261e+12 μg/s
# rco CO CO 9.31013e+13 μg/s
# rco CO2 CO2 1.23649e+15 μg/s
# rco EOH VOC 1.24079e+12 μg/s
# rco ETHERS VOC 6.40118e+11 μg/s
# rco HCOOH VOC 3.0891e+12 μg/s
# rco MEK VOC 1.08509e+11 μg/s
# rco NH3 NH3 1.31995e+12 μg/s
# rco NO NOx 3.03689e+12 μg/s
# rco OC PM2_5 4.23913e+12 μg/s
# rco OTHER_AROM VOC 1.24713e+11 μg/s
# rco OTHER_VOC VOC 4.0385e+09 μg/s
# rco PRPE VOC 9.41018e+11 μg/s
# rco SO2 SOx 3.15576e+12 μg/s
# rco TMB VOC 4.37748e+08 μg/s
# rco TOLU VOC 5.55009e+11 μg/s
# rco XYLE VOC 1.67228e+11 μg/s
# shp ALK4_butanes VOC 2.38903e+11 μg/s
# shp ALK4_hexanes VOC 1.36955e+11 μg/s
# shp ALK4_pentanes VOC 1.28235e+11 μg/s
# shp BC PM2_5 6.33118e+10 μg/s
# shp BENZ VOC 2.79065e+10 μg/s
# shp BUTENE VOC 6.39376e+09 μg/s
# shp C2H2 VOC 1.74375e+09 μg/s
# shp C2H4 VOC 6.07407e+10 μg/s
# shp C2H6 VOC 8.16838e+10 μg/s
# shp C3H8 VOC 2.26607e+11 μg/s
# shp CH4 CH4 9.76562e+09 μg/s
# shp CO CO 2.61375e+11 μg/s
# shp CO2 CO2 3.73155e+14 μg/s
# shp NH3 NH3 6.18116e+09 μg/s
# shp NO NOx 8.6181e+12 μg/s
# shp OC PM2_5 4.81208e+10 μg/s
# shp OTHER_AROM VOC 6.67523e+10 μg/s
# shp OTHER_VOC VOC 8.16709e+10 μg/s
# shp PRPE VOC 6.65532e+10 μg/s
# shp SO2 SOx 3.37894e+12 μg/s
# shp TMB VOC 1.07531e+10 μg/s
# shp TOLU VOC 1.68692e+10 μg/s
# shp XYLE VOC 1.77668e+10 μg/s
# slv ALK4_hexanes VOC 3.81983e+12 μg/s
# slv CHC VOC 1.58177e+11 μg/s
# slv CO2 CO2 1.90902e+13 μg/s
# slv EOH VOC 6.26453e+11 μg/s
# slv ESTERS VOC 7.23215e+11 μg/s
# slv ETHERS VOC 2.78865e+11 μg/s
# slv MEK VOC 8.85779e+11 μg/s
# slv OTHER_AROM VOC 1.56481e+11 μg/s
# slv OTHER_VOC VOC 4.94973e+11 μg/s
# slv TOLU VOC 7.93708e+11 μg/s
# slv XYLE VOC 7.87623e+11 μg/s
# tra ALD2 VOC 9.46012e+10 μg/s
# tra ALK4_butanes VOC 1.421e+12 μg/s
# tra ALK4_hexanes VOC 2.4304e+12 μg/s
# tra ALK4_pentanes VOC 1.8746e+12 μg/s
# tra BC PM2_5 5.37327e+11 μg/s
# tra BENZ VOC 3.21203e+11 μg/s
# tra BUTENE VOC 7.31041e+11 μg/s
# tra C2H2 VOC 3.95379e+11 μg/s
# tra C2H4 VOC 1.15982e+12 μg/s
# tra C2H6 VOC 1.30051e+11 μg/s
# tra C3H8 VOC 1.06364e+11 μg/s
# tra CH2O VOC 7.99658e+10 μg/s
# tra CH4 CH4 2.16117e+11 μg/s
# tra CO CO 5.6805e+13 μg/s
# tra CO2 CO2 2.27743e+15 μg/s
# tra MEK VOC 7.09778e+10 μg/s
# tra NH3 NH3 1.44624e+11 μg/s
# tra NO NOx 1.63509e+13 μg/s
# tra OC PM2_5 2.44335e+11 μg/s
# tra OTHER_AROM VOC 1.11967e+12 μg/s
# tra PRPE VOC 2.22576e+11 μg/s
# tra SO2 SOx 1.18071e+12 μg/s
# tra TMB VOC 4.96876e+11 μg/s
# tra TOLU VOC 5.61366e+11 μg/s
# tra XYLE VOC 4.77966e+11 μg/s
# wst ALD2 VOC 2.647e+10 μg/s
# wst ALK4_butanes VOC 9.47593e+10 μg/s
# wst ALK4_hexanes VOC 1.57426e+11 μg/s
# wst ALK4_pentanes VOC 8.72206e+10 μg/s
# wst BC PM2_5 2.57663e+11 μg/s
# wst BENZ VOC 6.81802e+10 μg/s
# wst BUTENE VOC 6.58527e+10 μg/s
# wst C2H2 VOC 4.47779e+10 μg/s
# wst C2H4 VOC 1.05375e+11 μg/s
# wst C2H6 VOC 7.34421e+10 μg/s
# wst C3H8 VOC 5.35843e+10 μg/s
# wst CH2O VOC 9.30784e+09 μg/s
# wst CH4 CH4 2.5002e+13 μg/s
# wst CHC VOC 2.26182e+09 μg/s
# wst CO CO 1.52941e+13 μg/s
# wst CO2 CO2 4.90368e+13 μg/s
# wst EOH VOC 6.58383e+10 μg/s
# wst ESTERS VOC 1.10345e+10 μg/s
# wst ETHERS VOC 3.29598e+10 μg/s
# wst HCOOH VOC 1.43376e+11 μg/s
# wst MEK VOC 1.67741e+10 μg/s
# wst NH3 NH3 3.45046e+12 μg/s
# wst NO NOx 2.28584e+12 μg/s
# wst OC PM2_5 1.60697e+12 μg/s
# wst OTHER_AROM VOC 3.18325e+10 μg/s
# wst OTHER_VOC VOC 1.53394e+12 μg/s
# wst PRPE VOC 5.09672e+10 μg/s
# wst SO2 SOx 2.04327e+11 μg/s
# wst TMB VOC 6.67446e+09 μg/s
# wst TOLU VOC 5.94282e+10 μg/s
# wst XYLE VOC 3.54571e+10 μg/s
